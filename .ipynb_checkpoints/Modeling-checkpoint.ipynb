# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
from scipy.spatial.distance import euclidean as euc
import numpy as np
from sklearn.datasets import make_classification
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import plot_confusion_matrix, plot_roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
np.random.seed(0)
import pickle
from sklearn.model_selection import GridSearchCV
import dtale

pd.set_option("display.max_rows", 600)
pd.set_option("display.max_columns", 60)
# %matplotlib inline

# %% [markdown]
# ## Pickling in "all_data_df"

# %%
with open("all_data.pickle", "rb") as to_read:
    all_data_df = pickle.load(to_read)

# %% [markdown]
# ## First attempt at logistic regression and KNN

# %%
# Using features I am suspecting will have high correlation
features = ["PTS", "AST", "PER"]
X = all_data_df[features]
y = all_data_df["All-Star next season?"]

# Test-train split
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=10)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=10)

# Scaling training set (for now) and testing set (for later)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# %%
# First logistic regression function
logr = LogisticRegression(penalty="none")
logr.fit(X_train_scaled, y_train)
val_predictions = logr.predict(X_val_scaled)
classification_report(y_val, val_predictions)

prob_predictions = logr.predict_proba(X_val_scaled)
prob_dict = dict(zip(list(X_val.index), list(prob_predictions)))

years_list = [year.split(", ")[1] for year in prob_dict.keys()]
years_list = list(set(years_list))
years_list.sort()
print(classification_report(y_val, val_predictions))

# Plotting in a confusion matrix
fig, ax = plt.subplots(figsize=(7, 7))
plot_confusion_matrix(logr, X_val_scaled, y_val, ax=ax, cmap="Oranges")
plt.savefig("First log confusion matrix (PTS, AST, PER)");

#for year in years_list:
    #eligible_players = [[player, list(chance)[1]] for player, chance in prob_dict.items() if player.split(", ")[1] == year]
    #top_24 = [[player, chance] for player, chance in sorted(eligible_players, key=lambda item: item[1], reverse=True)][:24]
    #print("Top 24 most likely All-Stars in {}: {}".format(year, (", ".join([all_star[0].split(", ")[0] for all_star in #top_24]))))
    #print("***********\nNext season...\n***********")
    
    
#top_20 = [[player, chance] for player, chance in sorted(prob_dict.items(), key=lambda item: item[1][1], reverse=True)][:20]
#top_20
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1325
#            1       0.77      0.51      0.61        81
#
#     accuracy                           0.96      1406
#    macro avg       0.87      0.75      0.80      1406
# weighted avg       0.96      0.96      0.96      1406

# %%
# Trying KNN
nn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
nn.fit(X_train_scaled, y_train)
predictions = nn.predict(X_val_scaled)

print(classification_report(y_val, predictions))

# Plotting in a confusion matrix
fig, ax = plt.subplots(figsize=(7, 7));
plot_confusion_matrix(nn, X_val_scaled, y_val, ax=ax, cmap="Oranges");
plt.savefig("First KNN confusion matrix (PTS, AST, PER)")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1325
#            1       0.63      0.40      0.48        81
#
#     accuracy                           0.95      1406
#    macro avg       0.80      0.69      0.73      1406
# weighted avg       0.94      0.95      0.95      1406

# %% [markdown]
# ## Next try

# %%
all_data_df.head()
# Out:
#                      Year         Player Pos   Age   Tm     G    GS      MP  \
# Player, year
# A.C. Green, 2000     2000     A.C. Green  PF  36.0  LAL  82.0  82.0  1929.0
# A.C. Green, 2001     2001     A.C. Green  PF  37.0  MIA  82.0   1.0  1411.0
# A.J. Bramlett, 2000  2000  A.J. Bramlett   C  23.0  CLE   8.0   0.0    61.0
# A.J. Guyton, 2001    2001    A.J. Guyton  PG  22.0  CHI  33.0   8.0   630.0
# A.J. Guyton, 2002    2002    A.J. Guyton  PG  23.0  CHI  45.0   6.0   607.0
#
#                       PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  \
# Player, year
# A.C. Green, 2000     11.2  0.482  0.010  0.245   9.0  17.9  13.5   5.9   1.4
# A.C. Green, 2001     11.2  0.492  0.019  0.343   9.0  17.3  13.2   4.8   1.2
# A.J. Bramlett, 2000  -0.4  0.190  0.000  0.000  21.7  18.5  20.1   0.0   0.8
# A.J. Guyton, 2001    10.3  0.495  0.359  0.094   1.8   5.1   3.4  18.1   0.8
# A.J. Guyton, 2002    11.8  0.477  0.504  0.111   2.3   6.3   4.2  23.6   0.9
#
#                      BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  \
# Player, year
# A.C. Green, 2000      0.7  11.0  11.0  1.7  3.3  5.0  0.124  -2.0   1.8  -0.2
# A.C. Green, 2001      0.4  10.8  14.4  1.1  2.1  3.2  0.110  -3.2   0.2  -3.0
# A.J. Bramlett, 2000   0.0  12.5  17.1 -0.2  0.1 -0.2 -0.129 -10.5  -6.3 -16.8
# A.J. Guyton, 2001     0.6  10.7  16.5  0.4 -0.1  0.3  0.020  -1.5  -4.4  -5.9
# A.J. Guyton, 2002     0.9  12.6  22.2  0.0  0.0  0.1  0.006  -0.3  -4.4  -4.7
#
#                      VORP     FG    FGA    FG%    3P    3PA    3P%     2P  \
# Player, year
# A.C. Green, 2000      0.9  173.0  387.0  0.447   1.0    4.0  0.250  172.0
# A.C. Green, 2001     -0.3  144.0  324.0  0.444   0.0    6.0  0.000  144.0
# A.J. Bramlett, 2000  -0.2    4.0   21.0  0.190   0.0    0.0    NaN    4.0
# A.J. Guyton, 2001    -0.6   78.0  192.0  0.406  27.0   69.0  0.391   51.0
# A.J. Guyton, 2002    -0.4   88.0  244.0  0.361  46.0  123.0  0.374   42.0
#
#                        2PA    2P%   eFG%    FT    FTA    FT%    ORB    DRB  \
# Player, year
# A.C. Green, 2000     383.0  0.449  0.448  66.0   95.0  0.695  160.0  326.0
# A.C. Green, 2001     318.0  0.453  0.444  79.0  111.0  0.712  107.0  206.0
# A.J. Bramlett, 2000   21.0  0.190  0.190   0.0    0.0    NaN   12.0   10.0
# A.J. Guyton, 2001    123.0  0.415  0.477  15.0   18.0  0.833   10.0   26.0
# A.J. Guyton, 2002    121.0  0.347  0.455  22.0   27.0  0.815   12.0   32.0
#
#                        TRB   AST   STL   BLK   TOV     PF    PTS  All-Star?  \
# Player, year
# A.C. Green, 2000     486.0  80.0  53.0  18.0  53.0  127.0  413.0          0
# A.C. Green, 2001     313.0  39.0  30.0   8.0  45.0  119.0  367.0          0
# A.J. Bramlett, 2000   22.0   0.0   1.0   0.0   3.0   13.0    8.0          0
# A.J. Guyton, 2001     36.0  64.0   9.0   5.0  24.0   35.0  198.0          0
# A.J. Guyton, 2002     44.0  81.0  10.0   7.0  37.0   23.0  244.0          0
#
#                     Selection process  All-Star next season?  TV market size
# Player, year
# A.C. Green, 2000                  N/a                      0       5354150.0
# A.C. Green, 2001                  N/a                      0       1468630.0
# A.J. Bramlett, 2000               N/a                      0       1488270.0
# A.J. Guyton, 2001                 N/a                      0       3244850.0
# A.J. Guyton, 2002                 N/a                      0       3244850.0

# %%
# Second attempt (adding "MP" and "Age")
features = ["PTS", "AST", "PER", "MP", "Age"]
X = all_data_df[features]
y = all_data_df["All-Star next season?"]

# Test-train split
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=10)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=10)

# Scaling training set (for now) and validation set (for later)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Instantiating and fitting
logr = LogisticRegression()
logr.fit(X_train_scaled, y_train)
val_predictions = logr.predict(X_val_scaled)
classification_report(y_val, val_predictions)

# Performance
print(classification_report(y_val, val_predictions))
fig, ax = plt.subplots(figsize=(7, 7));
plot_confusion_matrix(logr, X_val_scaled, y_val, ax=ax, cmap="Oranges");
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1325
#            1       0.79      0.51      0.62        81
#
#     accuracy                           0.96      1406
#    macro avg       0.88      0.75      0.80      1406
# weighted avg       0.96      0.96      0.96      1406

# %% [markdown]
# ## Using dtale

# %%
all_data_dtale = dtale.show(all_data_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-5c72d6ab43d0> in <module>
# ----> 1 all_data_dtale = dtale.show(all_data_df)
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/app.py in show(data, host, port, name, debug, subprocess, data_loader, reaper_on, open_browser, notebook, force, context_vars, ignore_duplicate, app_root, allow_cell_edits, inplace, drop_index, hide_shutdown, github_fork, **kwargs)
#     663         app_url = build_url(ACTIVE_PORT, ACTIVE_HOST)
#     664         startup_url, final_app_root = build_startup_url_and_app_root(app_root)
# --> 665         instance = startup(
#     666             startup_url,
#     667             data=data,
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/views.py in startup(url, data, data_loader, name, data_id, context_vars, ignore_duplicate, allow_cell_edits, inplace, drop_index, hide_shutdown, github_fork)
#     866         global_state.set_data(data_id, data)
#     867         global_state.set_dtypes(
# --> 868             data_id, build_dtypes_state(data, global_state.get_dtypes(data_id) or [])
#     869         )
#     870         global_state.set_context_variables(
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/views.py in build_dtypes_state(data, prev_state)
#     619         ranges = {}
#     620     dtype_f = dtype_formatter(data, get_dtypes(data), ranges, prev_dtypes)
# --> 621     return [dtype_f(i, c) for i, c in enumerate(data.columns)]
#     622
#     623
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/views.py in <listcomp>(.0)
#     619         ranges = {}
#     620     dtype_f = dtype_formatter(data, get_dtypes(data), ranges, prev_dtypes)
# --> 621     return [dtype_f(i, c) for i, c in enumerate(data.columns)]
#     622
#     623
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/views.py in _formatter(col_index, col)
#     560             index=col_index,
#     561             visible=visible,
# --> 562             unique_ct=unique_count(s),
#     563             hasMissing=int(s.isnull().sum()),
#     564             hasOutliers=0,
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/dtale/views.py in unique_count(s)
#     523
#     524 def unique_count(s):
# --> 525     return int(s.dropna().unique().size)
#     526
#     527
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/series.py in unique(self)
#    1866         Categories (3, object): ['a' < 'b' < 'c']
#    1867         """
# -> 1868         result = super().unique()
#    1869         return result
#    1870
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/base.py in unique(self)
#    1263                     result = np.asarray(result)
#    1264         else:
# -> 1265             result = unique1d(values)
#    1266
#    1267         return result
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/algorithms.py in unique(values)
#     387
#     388     table = htable(len(values))
# --> 389     uniques = table.unique(values)
#     390     uniques = _reconstruct_data(uniques, original.dtype, original)
#     391     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py in __hash__(self)
#    1663
#    1664     def __hash__(self):
# -> 1665         raise TypeError(
#    1666             f"{repr(type(self).__name__)} objects are mutable, "
#    1667             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
sklearn.model_selection.GridSearchCV()

param_grid = {'base_estimator__max_depth': [2, 4, 6, 8]}
search = GridSearchCV(logr, param_grid, cv=5)
search.fit(X, y)
GridSearchCV(cv=5,
             estimator=CalibratedClassifierCV(...),
             param_grid={'base_estimator__max_depth': [2, 4, 6, 8]})

# %%
ks = range(1, 30)

test_errors = np.zeros(len(list(ks)))

for i, k in enumerate(ks):
    
    nn = KNeighborsRegressor(n_neighbors=k, n_jobs=-1)

    nn.fit(X_train_scaled, y_train)
    test_preds = nn.predict(X_val_scaled)
    
    test_errors[i] = np.sqrt(mean_squared_error(y_val, test_preds))

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(list(ks), test_errors)
ax.axvline(list(ks)[np.argmin(test_errors)], linestyle='--', color='black');

# %%
optimal_k = list(ks)[np.argmin(test_errors)]

optimal_error = np.min(test_errors)

print(f'Optimal number of Neighbors: {optimal_k}\nRoot Mean Squared Error: {optimal_error:.2f}')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-209412d5524c> in <module>
# ----> 1 players
#
# NameError: name 'players' is not defined
